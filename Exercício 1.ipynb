# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (12.0, 9.0)

data = pd.read_csv('data1.txt')
X = data.iloc[:, 0]
Y = data.iloc[:, 1]

theta_1 = 0
theta_0 = 0

alpha = 0.01  # taxa de aprendizado
epochs = 100  # número de iterações
m = float(len(X)) # números de elementos de X

loss_function_values = []

for i in range(epochs):
    Y_pred = theta_1*X + theta_0 # Valor previsto para Y
    D_a = (-1/m) * sum(X * (Y - Y_pred))  # Derivada
    D_b = (-1/m) * sum(Y - Y_pred)  # Derivada
    theta_1 = theta_1 - alpha * D_a  # Atualiza o theta_1
    theta_0 = theta_0 - alpha * D_b  # Atualiza o theta_0
    err = 0
    for index, e in enumerate(X):
        err = err + (Y_pred[index] - Y[index])**2
    loss_function_values.append(1/(2*m) * err)
    
print ("Coeficiente a: " + str(theta_1) + "\nCoeficiente b: " + str(theta_0))

# Criando a função Y
Y_pred = theta_1*X + theta_0

# Plotando os valores com a regressão
plt.scatter(X, Y)
plt.plot([min(X), max(X)], [min(Y_pred), max(Y_pred)], color='red')  # regression line
plt.show()
# Out:
# Coeficiente a: 0.8549197441190249
# Coeficiente b: -0.6308876995749795

# %%
# Cálculo da função custo
X_loss = list(range(epochs))
Y_loss = loss_function_values # Valores dos erros de cada iteração
axes = plt.gca()
axes.set_xlim([0,epochs]) # obs: 
plt.plot(X_loss, Y_loss)
